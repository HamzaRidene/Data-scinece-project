# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pymongo
import time

# %%
from hdfs import InsecureClient
import os

# %%
cli= InsecureClient('http://localhost:9870')
with cli.read('Mytekk.csv',encoding='utf-16') as reader:
    df1=pd.read_csv(reader)

# %%
cli= InsecureClient('http://localhost:9870')
with cli.read('tunewtek.csv',encoding='utf-16') as reader:
    df=pd.read_csv(reader)

# %%
frames = [df1,df]
df_keys = pd.concat(frames, keys=['x', 'y'])
df_keys
# Out:
#      Unnamed: 0  Marque Memoire     carte graphique  Disque Dur  \
# x 0          ﻿0    ASUS    4 Go  Graphique Intégrée    1 To HDD
#   1          ﻿1      HP    4 Go  Graphique Intégrée    1 To HDD
#   2          ﻿2      HP    4 Go  Graphique Intégrée    1 To HDD
#   3          ﻿3      HP    4 Go  Graphique Intégrée    1 To HDD
#   4          ﻿4    ASUS    4 Go  Graphique Intégrée  128 Go SSD
# ...         ...     ...     ...                 ...         ...
# y 27        ﻿34  LENOVO    4 Go   Intel HD Graphics        1 To
#   28        ﻿35    ASUS    4 Go   Intel HD Graphics        1 To
#   29        ﻿36  LENOVO    4 Go   Intel HD Graphics        1 To
#   30        ﻿37    ASUS    4 Go   Intel HD Graphics  128 Go SSD
#   31        ﻿38  LENOVO    4 Go   Intel HD Graphics        1 To
#
#      Resolution Ecran Taille Ecran          Price
# x 0        1366 x 768  15.6 Pouces    819,000 TND
#   1        1366 x 768  15.6 Pouces    909,000 TND
#   2        1366 x 768  15.6 Pouces    999,000 TND
#   3        1366 x 768  15.6 Pouces    999,000 TND
#   4        1366 x 768    14 Pouces  1 029,000 TND
# ...               ...          ...            ...
# y 27       1366 x 768         15.6     994.000 DT
#   28       1366 x 768         15.6     998.000 DT
#   29       1366 x 768         15.6   1,018.000 DT
#   30      1920 X 1080           14   1,028.000 DT
#   31       1366 x 768         15.6   1,029.000 DT
#
# [385 rows x 8 columns]

# %%
df_keys.loc['y']
# Out:
#    Unnamed: 0  Marque Memoire    carte graphique  Disque Dur Resolution Ecran  \
# 0          ﻿0  LENOVO    4 Go  Intel HD Graphics      500 Go       1366 x 768
# 1          ﻿1  LENOVO    4 Go  Intel HD Graphics      500 Go       1366 x 768
# 2          ﻿2  LENOVO    4 Go  Intel HD Graphics      500 Go       1366 x 768
# 3          ﻿3  LENOVO    4 Go  Intel HD Graphics      500 Go       1366 x 768
# 4          ﻿4  LENOVO    4 Go  Intel HD Graphics      500 Go       1366 x 768
# 5          ﻿5  LENOVO    4 Go  Intel HD Graphics      500 Go       1366 x 768
# 6          ﻿6    ASUS    4 Go  Intel HD Graphics      500 Go       1366 x 768
# 7          ﻿7    DELL    4 Go  Intel HD Graphics      500 Go       1366 x 768
# 8          ﻿8  LENOVO    4 Go  Intel HD Graphics        1 To      1920 X 1080
# 9          ﻿9    ASUS    2 GO  Intel HD Graphics      500 Go       1366 x 768
# 10        ﻿10  LENOVO    4 Go  Intel HD Graphics  256 Go SSD      1920 X 1080
# 11        ﻿11    DELL    4 Go  Intel HD Graphics      500 Go       1366 x 768
# 12        ﻿12      HP    4 Go         AMD Radeon        1 To       1366 x 768
# 13        ﻿13    DELL    4 Go  Intel HD Graphics      500 Go       1366 x 768
# 14        ﻿14  LENOVO    4 Go  Intel HD Graphics        1 To       1366 x 768
# 15        ﻿15    ASUS    2 GO  Intel HD Graphics      500 Go       1366 x 768
# 16        ﻿16    ASUS    2 GO  Intel HD Graphics      500 Go       1366 x 768
# 17        ﻿17    ASUS    4 Go  Intel HD Graphics        1 To       1366 x 768
# 18        ﻿18  LENOVO    4 Go  Intel HD Graphics        1 To       1366 x 768
# 19        ﻿19  LENOVO    4 Go  Intel HD Graphics        1 To       1366 x 768
# 20        ﻿20    DELL    4 Go  Intel HD Graphics      500 Go       1366 x 768
# 21        ﻿21  LENOVO    4 Go  Intel HD Graphics        1 To       1366 x 768
# 22        ﻿22  LENOVO    4 Go  Intel HD Graphics        1 To       1366 x 768
# 23        ﻿23    ASUS    4 Go  Intel HD Graphics        1 To       1366 x 768
# 24        ﻿24  LENOVO    4 Go  Intel HD Graphics        1 To       1366 x 768
# 25        ﻿25  LENOVO    4 Go  Intel HD Graphics        1 To       1366 x 768
# 26        ﻿26  LENOVO    4 Go  Intel HD Graphics        1 To       1366 x 768
# 27        ﻿27  LENOVO    4 Go  Intel HD Graphics        1 To       1366 x 768
# 28        ﻿28  LENOVO    4 Go  Intel HD Graphics        1 To       1366 x 768
# 29        ﻿29    ASUS    4 Go  Intel HD Graphics      500 Go       1366 x 768
# 30        ﻿30    ASUS    4 Go  Intel HD Graphics      500 Go       1366 x 768
# 31        ﻿31  LENOVO    4 Go  Intel HD Graphics        1 To       1366 x 768
# 32        ﻿32    ASUS    4 Go  Intel HD Graphics        1 To       1366 x 768
# 33        ﻿33  LENOVO    4 Go         AMD Radeon        1 To       1366 x 768
# 34        ﻿34  LENOVO    4 Go  Intel HD Graphics        1 To       1366 x 768
# 35        ﻿35    ASUS    4 Go  Intel HD Graphics        1 To       1366 x 768
# 36        ﻿36  LENOVO    4 Go  Intel HD Graphics        1 To       1366 x 768
# 37        ﻿37    ASUS    4 Go  Intel HD Graphics  128 Go SSD      1920 X 1080
# 38        ﻿38  LENOVO    4 Go  Intel HD Graphics        1 To       1366 x 768
# 39        ﻿39  LENOVO    4 Go  Intel HD Graphics        1 To       1366 x 768
# 40        ﻿40  LENOVO    4 Go  Intel HD Graphics        1 To       1366 x 768
# 41        ﻿41  LENOVO    4 Go  Intel HD Graphics        1 To       1366 x 768
# 42        ﻿42    ACER    4 Go  Intel HD Graphics        1 To              NaN
# 43        ﻿43  LENOVO    4 Go  Intel HD Graphics        1 To              NaN
# 44        ﻿44    DELL    4 Go         AMD Radeon        1 To              NaN
# 45        ﻿45    DELL    4 Go  Intel HD Graphics        1 To              NaN
# 46        ﻿46    DELL    4 Go  Intel HD Graphics        1 To              NaN
# 47        ﻿47  LENOVO    4 Go  Intel HD Graphics        1 To              NaN
#
#    Taille Ecran                  Price
# 0          15.6             664.000 DT
# 1          15.6             668.000 DT
# 2          15.6             668.000 DT
# 3          15.6             668.000 DT
# 4          15.6             668.000 DT
# 5          15.6             668.000 DT
# 6          15.6             688.000 DT
# 7          15.6             698.000 DT
# 8          15.6             715.000 DT
# 9        11.6''             718.000 DT
# 10           14             728.000 DT
# 11         15.6             749.000 DT
# 12         15.6             758.000 DT
# 13         15.6             768.000 DT
# 14         15.6             768.000 DT
# 15       11.6''             789.000 DT
# 16       11.6''             789.000 DT
# 17         15.6             789.000 DT
# 18         15.6             819.000 DT
# 19         15.6             825.000 DT
# 20         15.6             828.000 DT
# 21         15.6             829.000 DT
# 22         15.6  889.000 DT 849.000 DT
# 23         15.6             865.000 DT
# 24         15.6             870.000 DT
# 25         15.6             879.000 DT
# 26         15.6             889.000 DT
# 27         15.6             889.000 DT
# 28           14             889.000 DT
# 29         15.6             898.000 DT
# 30         15.6             898.000 DT
# 31         15.6             910.000 DT
# 32         15.6             949.000 DT
# 33         15.6             988.000 DT
# 34         15.6             994.000 DT
# 35         15.6             998.000 DT
# 36         15.6           1,018.000 DT
# 37           14           1,028.000 DT
# 38         15.6           1,029.000 DT
# 39         15.6           1,029.000 DT
# 40         15.6           1,029.000 DT
# 41         15.6           1,029.000 DT
# 42         15.6           1,038.000 DT
# 43         15.6           1,049.000 DT
# 44         15.6           1,088.000 DT
# 45         15.6           1,088.000 DT
# 46         15.6           1,088.000 DT
# 47         15.6           1,088.000 DT

# %%
df_keys.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df_keys['Marque'].dropna()
# Out:
# x  0       ASUS
#    1         HP
#    2         HP
#    3         HP
#    4       ASUS
#           ...
# y  43    LENOVO
#    44      DELL
#    45      DELL
#    46      DELL
#    47    LENOVO
# Name: Marque, Length: 401, dtype: object

# %%
df_keys.shape
# Out:
# (401, 7)

# %%
df_keys.isnull().sum()
# Out:
# Marque              0
# Memoire             0
# carte graphique     0
# Disque Dur          0
# Resolution Ecran    6
# Taille Ecran        0
# Price               0
# dtype: int64

# %%
df_keys['Memoire'] = df_keys['Memoire'].str.replace('Go','')

# %%
df_keys['Price'].dtype
# Out:
# dtype('O')

# %%
df_keys['Price'] = df_keys['Price'].str.replace('DT','')
df_keys['Price'] = df_keys['Price'].str.replace('TND','')
#\xa0TND
#df_keys['Price']= df_keys['Price'].replace('\xa0','')

# %%
df_keys
# Out:
#       Marque Memoire     carte graphique  Disque Dur Resolution Ecran  \
# x 0     ASUS      4   Graphique Intégrée    1 To HDD       1366 x 768
#   1       HP      4   Graphique Intégrée    1 To HDD       1366 x 768
#   2       HP      4   Graphique Intégrée    1 To HDD       1366 x 768
#   3       HP      4   Graphique Intégrée    1 To HDD       1366 x 768
#   4     ASUS      4   Graphique Intégrée  128 Go SSD       1366 x 768
# ...      ...     ...                 ...         ...              ...
# y 43  LENOVO      4    Intel HD Graphics        1 To              NaN
#   44    DELL      4           AMD Radeon        1 To              NaN
#   45    DELL      4    Intel HD Graphics        1 To              NaN
#   46    DELL      4    Intel HD Graphics        1 To              NaN
#   47  LENOVO      4    Intel HD Graphics        1 To              NaN
#
#      Taille Ecran       Price
# x 0   15.6 Pouces    819,000
#   1   15.6 Pouces    909,000
#   2   15.6 Pouces    999,000
#   3   15.6 Pouces    999,000
#   4     14 Pouces  1 029,000
# ...           ...         ...
# y 43         15.6  1,049.000
#   44         15.6  1,088.000
#   45         15.6  1,088.000
#   46         15.6  1,088.000
#   47         15.6  1,088.000
#
# [401 rows x 7 columns]

# %%
df_keys['Price'] = df_keys['Price'].str.replace('\xa0','')
df_keys['Price'] = df_keys['Price'].str.replace('\u202f','')

df_keys['Price'] = df_keys['Price'].str.replace('889.000 849.000','849.000')
df_keys['Price'] = df_keys['Price'].str.replace('1.018.000','1018.000')
df_keys['Price'] = df_keys['Price'].str.replace('1.028.000','1028.000')
df_keys['Price'] = df_keys['Price'].str.replace('1.029.000','1029.000')


#df_keys['Price'] = df_keys['Price'].loc['y'].str.replace('1,','1')

# %%
df_keys.loc['y',30].Price
# Out:
# '898.000'

# %%
df_keys
# Out:
#       Marque Memoire     carte graphique  Disque Dur Resolution Ecran  \
# x 0     ASUS      4   Graphique Intégrée    1 To HDD       1366 x 768
#   1       HP      4   Graphique Intégrée    1 To HDD       1366 x 768
#   2       HP      4   Graphique Intégrée    1 To HDD       1366 x 768
#   3       HP      4   Graphique Intégrée    1 To HDD       1366 x 768
#   4     ASUS      4   Graphique Intégrée  128 Go SSD       1366 x 768
# ...      ...     ...                 ...         ...              ...
# y 43  LENOVO      4    Intel HD Graphics        1 To              NaN
#   44    DELL      4           AMD Radeon        1 To              NaN
#   45    DELL      4    Intel HD Graphics        1 To              NaN
#   46    DELL      4    Intel HD Graphics        1 To              NaN
#   47  LENOVO      4    Intel HD Graphics        1 To              NaN
#
#      Taille Ecran      Price
# x 0   15.6 Pouces    819,000
#   1   15.6 Pouces    909,000
#   2   15.6 Pouces    999,000
#   3   15.6 Pouces    999,000
#   4     14 Pouces   1029,000
# ...           ...        ...
# y 43         15.6  1,049.000
#   44         15.6  1,088.000
#   45         15.6  1,088.000
#   46         15.6  1,088.000
#   47         15.6  1,088.000
#
# [401 rows x 7 columns]

# %%
import re

# %%
df_keys['Price']=df_keys['Price'].replace('[^\d.]','',regex=True).astype(float)

# %%
df_keys['Price'].astype('float64')
# Out:
# x  0      819000.0
#    1      909000.0
#    2      999000.0
#    3      999000.0
#    4     1029000.0
#            ...
# y  43       1049.0
#    44       1088.0
#    45       1088.0
#    46       1088.0
#    47       1088.0
# Name: Price, Length: 401, dtype: float64

# %%
import seaborn as sns

# %%
sns.distplot(df_keys['Price'].loc['y'])

# %%
sns.distplot(df_keys['Price'].loc['x'])

# %%
df_keys['Marque'].value_counts().plot(kind='bar')

# %%
sns.barplot(x=df_keys['Marque'],y=df_keys['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df_keys['Resolution Ecran'],y=df_keys['Price'])
plt.xticks(rotation='vertical')
plt.yticks(rotation='vertical')
plt.show()

# %%
df_keys['Resolution Ecran'].value_counts().plot(kind='bar')

# %%
new = df_keys['Resolution Ecran'].str.split('x',n=1,expand=True)

# %%
df_keys['X_res'] = new[0]
df_keys['Y_res'] = new[1]

# %%
df_keys
# Out:
#       Marque Memoire     carte graphique  Disque Dur Resolution Ecran  \
# x 0     ASUS      4   Graphique Intégrée    1 To HDD       1366 x 768
#   1       HP      4   Graphique Intégrée    1 To HDD       1366 x 768
#   2       HP      4   Graphique Intégrée    1 To HDD       1366 x 768
#   3       HP      4   Graphique Intégrée    1 To HDD       1366 x 768
#   4     ASUS      4   Graphique Intégrée  128 Go SSD       1366 x 768
# ...      ...     ...                 ...         ...              ...
# y 43  LENOVO      4    Intel HD Graphics        1 To              NaN
#   44    DELL      4           AMD Radeon        1 To              NaN
#   45    DELL      4    Intel HD Graphics        1 To              NaN
#   46    DELL      4    Intel HD Graphics        1 To              NaN
#   47  LENOVO      4    Intel HD Graphics        1 To              NaN
#
#      Taille Ecran      Price  X_res Y_res
# x 0   15.6 Pouces   819000.0  1366    768
#   1   15.6 Pouces   909000.0  1366    768
#   2   15.6 Pouces   999000.0  1366    768
#   3   15.6 Pouces   999000.0  1366    768
#   4     14 Pouces  1029000.0  1366    768
# ...           ...        ...    ...   ...
# y 43         15.6     1049.0    NaN   NaN
#   44         15.6     1088.0    NaN   NaN
#   45         15.6     1088.0    NaN   NaN
#   46         15.6     1088.0    NaN   NaN
#   47         15.6     1088.0    NaN   NaN
#
# [401 rows x 9 columns]

# %%
df_keys['Taille Ecran']=df_keys['Taille Ecran'].str.replace('Pouces','')

# %%
df_keys
# Out:
#       Marque Memoire     carte graphique  Disque Dur Resolution Ecran  \
# x 0     ASUS      4   Graphique Intégrée    1 To HDD       1366 x 768
#   1       HP      4   Graphique Intégrée    1 To HDD       1366 x 768
#   2       HP      4   Graphique Intégrée    1 To HDD       1366 x 768
#   3       HP      4   Graphique Intégrée    1 To HDD       1366 x 768
#   4     ASUS      4   Graphique Intégrée  128 Go SSD       1366 x 768
# ...      ...     ...                 ...         ...              ...
# y 43  LENOVO      4    Intel HD Graphics        1 To              NaN
#   44    DELL      4           AMD Radeon        1 To              NaN
#   45    DELL      4    Intel HD Graphics        1 To              NaN
#   46    DELL      4    Intel HD Graphics        1 To              NaN
#   47  LENOVO      4    Intel HD Graphics        1 To              NaN
#
#      Taille Ecran      Price  X_res Y_res
# x 0         15.6    819000.0  1366    768
#   1         15.6    909000.0  1366    768
#   2         15.6    999000.0  1366    768
#   3         15.6    999000.0  1366    768
#   4           14   1029000.0  1366    768
# ...           ...        ...    ...   ...
# y 43         15.6     1049.0    NaN   NaN
#   44         15.6     1088.0    NaN   NaN
#   45         15.6     1088.0    NaN   NaN
#   46         15.6     1088.0    NaN   NaN
#   47         15.6     1088.0    NaN   NaN
#
# [401 rows x 9 columns]

# %%
df_keys=df_keys[~df_keys['X_res'].isnull()]
df_keys=df_keys[~df_keys['Y_res'].isnull()]

# %%
df_keys
# Out:
#       Marque Memoire     carte graphique  Disque Dur Resolution Ecran  \
# x 0     ASUS      4   Graphique Intégrée    1 To HDD       1366 x 768
#   1       HP      4   Graphique Intégrée    1 To HDD       1366 x 768
#   2       HP      4   Graphique Intégrée    1 To HDD       1366 x 768
#   3       HP      4   Graphique Intégrée    1 To HDD       1366 x 768
#   4     ASUS      4   Graphique Intégrée  128 Go SSD       1366 x 768
# ...      ...     ...                 ...         ...              ...
# y 36  LENOVO      4    Intel HD Graphics        1 To       1366 x 768
#   38  LENOVO      4    Intel HD Graphics        1 To       1366 x 768
#   39  LENOVO      4    Intel HD Graphics        1 To       1366 x 768
#   40  LENOVO      4    Intel HD Graphics        1 To       1366 x 768
#   41  LENOVO      4    Intel HD Graphics        1 To       1366 x 768
#
#      Taille Ecran      Price  X_res Y_res
# x 0         15.6    819000.0  1366    768
#   1         15.6    909000.0  1366    768
#   2         15.6    999000.0  1366    768
#   3         15.6    999000.0  1366    768
#   4           14   1029000.0  1366    768
# ...           ...        ...    ...   ...
# y 36         15.6     1018.0  1366    768
#   38         15.6     1029.0  1366    768
#   39         15.6     1029.0  1366    768
#   40         15.6     1029.0  1366    768
#   41         15.6     1029.0  1366    768
#
# [392 rows x 9 columns]

# %%
df_keys['X_res'] = df_keys['X_res'].astype('float')
df_keys['Y_res'] = df_keys['Y_res'].astype('float')

# %%
df_keys['Memoire'] = df_keys['Memoire'].str.replace('GO','')

# %%
df_keys['Taille Ecran'] = df_keys['Taille Ecran'].str.replace("''",'')

# %%
df_keys['Memoire'] = df_keys['Memoire'].astype('int32')
df_keys['Taille Ecran']=df_keys['Taille Ecran'].astype('float64')

# %%
df_keys.corr()['Price']
# Out:
# Memoire         0.520601
# Taille Ecran   -0.057674
# Price           1.000000
# X_res           0.654603
# Y_res           0.635493
# Name: Price, dtype: float64

# %%
sns.distplot(df_keys['Taille Ecran'])
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
sns.scatterplot(x=df_keys['Taille Ecran'],y=df_keys['Price'])

# %%
df_keys['ppi'] = (((df_keys['X_res']**2) + (df_keys['Y_res']**2))**0.5/df_keys['Taille Ecran']).astype('float')

# %%
df_keys.corr()['Price']
# Out:
# Memoire         0.520601
# Taille Ecran   -0.057674
# Price           1.000000
# X_res           0.654603
# Y_res           0.635493
# ppi             0.585591
# Name: Price, dtype: float64

# %%
df_keys
# Out:
#       Marque  Memoire     carte graphique  Disque Dur Resolution Ecran  \
# x 0     ASUS        4  Graphique Intégrée    1 To HDD       1366 x 768
#   1       HP        4  Graphique Intégrée    1 To HDD       1366 x 768
#   2       HP        4  Graphique Intégrée    1 To HDD       1366 x 768
#   3       HP        4  Graphique Intégrée    1 To HDD       1366 x 768
#   4     ASUS        4  Graphique Intégrée  128 Go SSD       1366 x 768
# ...      ...      ...                 ...         ...              ...
# y 36  LENOVO        4   Intel HD Graphics        1 To       1366 x 768
#   38  LENOVO        4   Intel HD Graphics        1 To       1366 x 768
#   39  LENOVO        4   Intel HD Graphics        1 To       1366 x 768
#   40  LENOVO        4   Intel HD Graphics        1 To       1366 x 768
#   41  LENOVO        4   Intel HD Graphics        1 To       1366 x 768
#
#       Taille Ecran      Price   X_res  Y_res         ppi
# x 0           15.6   819000.0  1366.0  768.0  100.454670
#   1           15.6   909000.0  1366.0  768.0  100.454670
#   2           15.6   999000.0  1366.0  768.0  100.454670
#   3           15.6   999000.0  1366.0  768.0  100.454670
#   4           14.0  1029000.0  1366.0  768.0  111.935204
# ...            ...        ...     ...    ...         ...
# y 36          15.6     1018.0  1366.0  768.0  100.454670
#   38          15.6     1029.0  1366.0  768.0  100.454670
#   39          15.6     1029.0  1366.0  768.0  100.454670
#   40          15.6     1029.0  1366.0  768.0  100.454670
#   41          15.6     1029.0  1366.0  768.0  100.454670
#
# [392 rows x 10 columns]

# %%
df_keys.drop(columns=['Taille Ecran','X_res','Y_res'],inplace=True)

# %%
df_keys.head()
# Out:
#     Marque  Memoire     carte graphique  Disque Dur Resolution Ecran  \
# x 0   ASUS        4  Graphique Intégrée    1 To HDD       1366 x 768
#   1     HP        4  Graphique Intégrée    1 To HDD       1366 x 768
#   2     HP        4  Graphique Intégrée    1 To HDD       1366 x 768
#   3     HP        4  Graphique Intégrée    1 To HDD       1366 x 768
#   4   ASUS        4  Graphique Intégrée  128 Go SSD       1366 x 768
#
#          Price         ppi
# x 0   819000.0  100.454670
#   1   909000.0  100.454670
#   2   999000.0  100.454670
#   3   999000.0  100.454670
#   4  1029000.0  111.935204

# %%
df_keys['Disque Dur'].value_counts()
# Out:
# 1 To HDD           146
# 512Go SSD          114
# 256 Go SSD          58
# 1 To                23
# 500 Go              16
# 1To + 256Go SSD     11
# 1 To SSD             8
# 1To + 512Go SSD      8
# 1To + 128Go SSD      3
# 128 Go SSD           2
# 128 Go eMMC          2
# 2To + 512Go SSD      1
# Name: Disque Dur, dtype: int64

# %%
df_keys['Disque Dur'] = df_keys['Disque Dur'].astype(str).replace('\.0', '', regex=True)
df_keys["Disque Dur"] = df_keys["Disque Dur"].str.replace('Go', '')
df_keys["Disque Dur"] = df_keys["Disque Dur"].str.replace('To', '000')
new = df_keys["Disque Dur"].str.split("+", n = 1, expand = True)

df_keys["first"]= new[0]
df_keys["first"].fillna("0", inplace = True)
df_keys["first"]=df_keys["first"].str.strip()
df_keys["second"]= new[1]
df_keys["Layer1HDD"] = df_keys["first"].apply(lambda x: 1 if "HDD" in x else 0)
df_keys["Layer1SSD"] = df_keys["first"].apply(lambda x: 1 if "SSD" in x else 0)

df_keys["Layer1eMMC"] = df_keys["first"].apply(lambda x: 1 if "eMMC" in x else 0)
df_keys['first'] = df_keys['first'].str.replace(r'\D', '')

df_keys["second"].fillna("0", inplace = True)
df_keys["Layer2HDD"] = df_keys["second"].apply(lambda x: 1 if "HDD" in x else 0)
df_keys["Layer2SSD"] = df_keys["second"].apply(lambda x: 1 if "SSD" in x else 0)
df_keys["Layer2eMMC"] = df_keys["second"].apply(lambda x: 1 if "eMMC" in x else 0)

df_keys['second'] = df_keys['second'].str.replace(r'\D', '')

df_keys["first"] = df_keys["first"].astype(int)
df_keys["second"] = df_keys["second"].astype(int)
df_keys["HDD"]=(df_keys["first"]*df_keys["Layer1HDD"]+df_keys["second"]*df_keys["Layer2HDD"])
df_keys["SSD"]=(df_keys["first"]*df_keys["Layer1SSD"]+df_keys["second"]*df_keys["Layer2SSD"])
df_keys["eMMC"]=(df_keys["first"]*df_keys["Layer1eMMC"]+df_keys["second"]*df_keys["Layer2eMMC"])
df_keys.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 
       'Layer1eMMC', 'Layer2HDD', 'Layer2SSD',
       'Layer2eMMC'],inplace=True)

# %%
df_keys.sample(5)
# Out:
#        Marque  Memoire    carte graphique Disque Dur Resolution Ecran  \
# y 5    LENOVO        4  Intel HD Graphics       500        1366 x 768
# x 319     MSI       16     Nvidia GeForce    512 SSD      1920 x 1080
#   205  LENOVO        8     Nvidia GeForce  1 000 HDD      1920 x 1080
#   227    ASUS        8     Nvidia GeForce    512 SSD      1920 x 1080
# y 9      ASUS        2  Intel HD Graphics       500        1366 x 768
#
#            Price         ppi   HDD  SSD  eMMC
# y 5        668.0  100.454670     0    0     0
# x 319  4479000.0  127.335675     0  512     0
#   205  2539000.0  157.350512  1000    0     0
#   227  2749000.0  141.211998     0  512     0
# y 9        718.0  135.094211     0    0     0

# %%
df_keys.corr()['Price']
# Out:
# Memoire    0.520601
# Price      1.000000
# ppi        0.585591
# HDD       -0.330675
# SSD        0.741921
# eMMC      -0.063570
# Name: Price, dtype: float64

# %%
df_keys['carte graphique'].value_counts()
# Out:
# Graphique Intégrée    201
# Nvidia GeForce        146
# Intel HD Graphics      37
# AMD Radeon              8
# Name: carte graphique, dtype: int64

# %%
df_keys['Gpu brand'] = df_keys['carte graphique'].apply(lambda x:x.split()[0])

# %%
df_keys.head()
# Out:
#     Marque  Memoire     carte graphique Disque Dur Resolution Ecran  \
# x 0   ASUS        4  Graphique Intégrée  1 000 HDD       1366 x 768
#   1     HP        4  Graphique Intégrée  1 000 HDD       1366 x 768
#   2     HP        4  Graphique Intégrée  1 000 HDD       1366 x 768
#   3     HP        4  Graphique Intégrée  1 000 HDD       1366 x 768
#   4   ASUS        4  Graphique Intégrée   128  SSD       1366 x 768
#
#          Price         ppi   HDD  SSD  eMMC  Gpu brand
# x 0   819000.0  100.454670  1000    0     0  Graphique
#   1   909000.0  100.454670  1000    0     0  Graphique
#   2   999000.0  100.454670  1000    0     0  Graphique
#   3   999000.0  100.454670  1000    0     0  Graphique
#   4  1029000.0  111.935204     0  128     0  Graphique

# %%
df_keys['Gpu brand'].value_counts()
# Out:
# Graphique    201
# Nvidia       146
# Intel         37
# AMD            8
# Name: Gpu brand, dtype: int64

# %%
df_keys.head()
# Out:
#     Marque  Memoire     carte graphique Disque Dur Resolution Ecran  \
# x 0   ASUS        4  Graphique Intégrée  1 000 HDD       1366 x 768
#   1     HP        4  Graphique Intégrée  1 000 HDD       1366 x 768
#   2     HP        4  Graphique Intégrée  1 000 HDD       1366 x 768
#   3     HP        4  Graphique Intégrée  1 000 HDD       1366 x 768
#   4   ASUS        4  Graphique Intégrée   128  SSD       1366 x 768
#
#          Price         ppi   HDD  SSD  eMMC  Gpu brand
# x 0   819000.0  100.454670  1000    0     0  Graphique
#   1   909000.0  100.454670  1000    0     0  Graphique
#   2   999000.0  100.454670  1000    0     0  Graphique
#   3   999000.0  100.454670  1000    0     0  Graphique
#   4  1029000.0  111.935204     0  128     0  Graphique

# %%
sns.barplot(x=df_keys['Gpu brand'],y=df_keys['Price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
df_keys.drop(columns=['carte graphique'],inplace=True)

# %%
df_keys.head()
# Out:
#     Marque  Memoire Disque Dur Resolution Ecran      Price         ppi   HDD  \
# x 0   ASUS        4  1 000 HDD       1366 x 768   819000.0  100.454670  1000
#   1     HP        4  1 000 HDD       1366 x 768   909000.0  100.454670  1000
#   2     HP        4  1 000 HDD       1366 x 768   999000.0  100.454670  1000
#   3     HP        4  1 000 HDD       1366 x 768   999000.0  100.454670  1000
#   4   ASUS        4   128  SSD       1366 x 768  1029000.0  111.935204     0
#
#      SSD  eMMC  Gpu brand
# x 0    0     0  Graphique
#   1    0     0  Graphique
#   2    0     0  Graphique
#   3    0     0  Graphique
#   4  128     0  Graphique

# %%
df_keys.drop(columns=['Resolution Ecran'],inplace=True)

# %%
df_keys.corr()['Price']
# Out:
# Memoire    0.520601
# Price      1.000000
# ppi        0.585591
# HDD       -0.330675
# SSD        0.741921
# eMMC      -0.063570
# Name: Price, dtype: float64

# %%
sns.heatmap(df_keys.corr())

# %%
sns.distplot(np.log(df_keys['Price']))

# %%
X = df_keys.drop(columns=['Price'])
y = np.log(df_keys['Price'])

# %%
X
# Out:
#       Marque  Memoire         ppi   HDD  SSD  eMMC  Gpu brand
# x 0     ASUS        4  100.454670  1000    0     0  Graphique
#   1       HP        4  100.454670  1000    0     0  Graphique
#   2       HP        4  100.454670  1000    0     0  Graphique
#   3       HP        4  100.454670  1000    0     0  Graphique
#   4     ASUS        4  111.935204     0  128     0  Graphique
# ...      ...      ...         ...   ...  ...   ...        ...
# y 36  LENOVO        4  100.454670     0    0     0      Intel
#   38  LENOVO        4  100.454670     0    0     0      Intel
#   39  LENOVO        4  100.454670     0    0     0      Intel
#   40  LENOVO        4  100.454670     0    0     0      Intel
#   41  LENOVO        4  100.454670     0    0     0      Intel
#
# [392 rows x 7 columns]

# %%
y
# Out:
# x  0     13.615839
#    1     13.720100
#    2     13.814510
#    3     13.814510
#    4     13.844098
#            ...
# y  36     6.925595
#    38     6.936343
#    39     6.936343
#    40     6.936343
#    41     6.936343
# Name: Price, Length: 392, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#                Marque  Memoire         ppi   HDD  SSD  eMMC  Gpu brand
# x 279            ASUS       16  157.350512     0  512     0  Graphique
#   114              HP       20  100.454670  1000    0     0  Graphique
#   109              HP        8  100.454670     0  256     0  Graphique
#   94             ACER        8  100.454670  1000    0     0  Graphique
# y 40           LENOVO        4  100.454670     0    0     0      Intel
# ...               ...      ...         ...   ...  ...   ...        ...
# x 299           Apple        8  232.221074     0  256     0  Graphique
#   22             ACER        8  100.454670  1000    0     0  Graphique
#   72   Sans Fabricant        4  141.211998     0  256     0  Graphique
#   15             ASUS        8  111.935204  1000    0     0  Graphique
#   168              HP       32  100.454670  1000    0     0  Graphique
#
# [333 rows x 7 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
#Linear regression
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,6])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.9373890025002474
# MAE 0.2791519514167116

# %%
#Ridge Regression
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,6])
],remainder='passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8884701453815591
# MAE 0.5020852292521362

# %%
#Lasso Regression
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,6])
],remainder='passthrough')

step2 = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.9407046507016821
# MAE 0.2700552758983163

# %%
#KNN
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,6])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.9901645432385928
# MAE 0.1641586369227123

# %%
#Decision Tree
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,6])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.9913895283635704
# MAE 0.14395312490862133

# %%
#SVM
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,6])
],remainder='passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.9873262472713724
# MAE 0.17585026302715592

# %%
#Random Forest
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,6])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.9885027626212415
# MAE 0.16851878307154555

# %%
#XGBOOST
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,6])
],remainder='passthrough')

step2 = XGBRegressor(n_estimators=45,max_depth=5,learning_rate=0.5)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.988181663331317
# MAE 0.1677557132855686

# %%
#Voting Regressor
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,6])
],remainder='passthrough')


rf = RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)
gbdt = GradientBoostingRegressor(n_estimators=100,max_features=0.5)
xgb = XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5)
et = ExtraTreesRegressor(n_estimators=100,random_state=3,max_samples=0.5,max_features=0.75,max_depth=10)

step2 = VotingRegressor([('rf', rf), ('gbdt', gbdt), ('xgb',xgb), ('et',et)],weights=[5,1,1,1])

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.9896576563837503
# MAE 0.15898889445383474

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,6])
],remainder='passthrough')


estimators = [
    ('rf', RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)),
    ('gbdt',GradientBoostingRegressor(n_estimators=100,max_features=0.5)),
    ('xgb', XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5))
]

step2 = StackingRegressor(estimators=estimators, final_estimator=Ridge(alpha=100))

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.9893327375528418
# MAE 0.1597836538768466

# %%
import pickle

pickle.dump(df_keys,open('df_keys.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))
